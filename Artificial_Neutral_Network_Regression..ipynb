# %% [markdown]
# <a href="https://colab.research.google.com/github/d1m3j1/Machine-Learning/blob/main/Artificial_Neutral_Network_Regression..ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### **Artificial Neutral Network with Regression.**

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt

# %%
#Make the dataset
N = 1000
X = np.random.random((N, 2)) * 6 - 3
Y = np.cos(2 * X[:,0] + np.cos(3 * X[:, 1]))

# %%
#plot it
fig = plt.figure()
ax = fig.add_subplot(111, projection = '3d')
ax.scatter(X[:, 0], X[:, 1], Y)

# %%
#Build the model
model = tf.keras.models.Sequential([
  tf.keras.layers.Dense(128, input_shape = (2,), activation = 'relu'),
  tf.keras.layers.Dense(1)
])

# %%
#Compile and fit the model
opt = tf.keras.optimizers.Adam(0.01)
model.compile(optimizer = opt, loss = 'mse')
r = model.fit(X, Y, epochs = 100)
# Out:
# Epoch 1/100
# 32/32 [==============================] - 1s 931us/step - loss: 0.5213
# Epoch 2/100
# 32/32 [==============================] - 0s 971us/step - loss: 0.5073
# Epoch 3/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.4663
# Epoch 4/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.4614
# Epoch 5/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.4232
# Epoch 6/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.4071
# Epoch 7/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.3411
# Epoch 8/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.2985
# Epoch 9/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.3040
# Epoch 10/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.2489
# Epoch 11/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.2610
# Epoch 12/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.2234
# Epoch 13/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.2437
# Epoch 14/100
# 32/32 [==============================] - 0s 995us/step - loss: 0.2110
# Epoch 15/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.2426
# Epoch 16/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.2177
# Epoch 17/100
# 32/32 [==============================] - 0s 930us/step - loss: 0.2228
# Epoch 18/100
# 32/32 [==============================] - 0s 998us/step - loss: 0.2166
# Epoch 19/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.2436
# Epoch 20/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.1986
# Epoch 21/100
# 32/32 [==============================] - 0s 965us/step - loss: 0.2013
# Epoch 22/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.1995
# Epoch 23/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.2079
# Epoch 24/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.2007
# Epoch 25/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.2032
# Epoch 26/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.2576
# Epoch 27/100
# 32/32 [==============================] - 0s 993us/step - loss: 0.1895
# Epoch 28/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.2182
# Epoch 29/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.1995
# Epoch 30/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.2031
# Epoch 31/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.2328
# Epoch 32/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.2186
# Epoch 33/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.2255
# Epoch 34/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.1906
# Epoch 35/100
# 32/32 [==============================] - 0s 958us/step - loss: 0.2015
# Epoch 36/100
# 32/32 [==============================] - 0s 995us/step - loss: 0.1948
# Epoch 37/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.2082
# Epoch 38/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.2027
# Epoch 39/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.1776
# Epoch 40/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.1856
# Epoch 41/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.1827
# Epoch 42/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.1852
# Epoch 43/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.1815
# Epoch 44/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.1825
# Epoch 45/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.2002
# Epoch 46/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.1865
# Epoch 47/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.1765
# Epoch 48/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.1605
# Epoch 49/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.2052
# Epoch 50/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.2445
# Epoch 51/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.1732
# Epoch 52/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.1749
# Epoch 53/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.2285
# Epoch 54/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.1634
# Epoch 55/100
# 32/32 [==============================] - 0s 978us/step - loss: 0.1590
# Epoch 56/100
# 32/32 [==============================] - 0s 991us/step - loss: 0.1587
# Epoch 57/100
# 32/32 [==============================] - 0s 997us/step - loss: 0.1763
# Epoch 58/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.1812
# Epoch 59/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.2039
# Epoch 60/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.1522
# Epoch 61/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.1721
# Epoch 62/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.1455
# Epoch 63/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.2053
# Epoch 64/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.1692
# Epoch 65/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.1588
# Epoch 66/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.1678
# Epoch 67/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.1535
# Epoch 68/100
# 32/32 [==============================] - 0s 984us/step - loss: 0.1537
# Epoch 69/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.1458
# Epoch 70/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.1482
# Epoch 71/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.1354
# Epoch 72/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.1772
# Epoch 73/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.1453
# Epoch 74/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.1613
# Epoch 75/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.1626
# Epoch 76/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.1354
# Epoch 77/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.1658
# Epoch 78/100
# 32/32 [==============================] - 0s 999us/step - loss: 0.1425
# Epoch 79/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.1543
# Epoch 80/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.1540
# Epoch 81/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.1625
# Epoch 82/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.1432
# Epoch 83/100
# 32/32 [==============================] - 0s 998us/step - loss: 0.1455
# Epoch 84/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.1491
# Epoch 85/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.1477
# Epoch 86/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.1340
# Epoch 87/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.1530
# Epoch 88/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.1371
# Epoch 89/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.1324
# Epoch 90/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.1240
# Epoch 91/100
# 32/32 [==============================] - 0s 993us/step - loss: 0.1299
# Epoch 92/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.1414
# Epoch 93/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.1285
# Epoch 94/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.1127
# Epoch 95/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.1197
# Epoch 96/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.1221
# Epoch 97/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.1273
# Epoch 98/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.1238
# Epoch 99/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.1285
# Epoch 100/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.1381

# %%
#Plot the loss
plt.plot(r.history['loss'], label = 'loss')

# %%
#Plot the prediction surface
fig = plt.figure()
ax = fig.add_subplot(111, projection = '3d')
ax.scatter(X[:, 0], X[:, 1], Y)

#surface plot
line = np.linspace(-3, 3, 50)
xx, yy = np.meshgrid(line, line)
Xgrid = np.vstack((xx.flatten(), yy.flatten())).T
Yhat = model.predict(Xgrid).flatten()
ax.plot_trisurf(Xgrid[:, 0], Xgrid[:, 1], Yhat, linewidth = 0.2, antialiased = True)
plt.show()

# %%
#Plot the predictoin surface
fig = plt.figure()
ax = fig.add_subplot(111, projection = '3d')
ax.scatter(X[:, 0], X[:, 1], Y)

#surface plot
line = np.linspace(-5, 5, 50)
xx, yy = np.meshgrid(line, line)
Xgrid = np.vstack((xx.flatten(), yy.flatten())).T
Yhat = model.predict(Xgrid).flatten()
ax.plot_trisurf(Xgrid[:, 0], Xgrid[:, 1], Yhat, linewidth = 0.2, antialiased = True)
plt.show()
